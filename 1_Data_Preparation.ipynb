# %% [markdown]
# # Data Preparation and Feature augmentation and engineering

# %% [markdown]
# ### House Transactions dataset
#
# Steps to follow:
#
# - Read data and join with postocdes to geolocate
# - Upload to GIS server

# %%
import pandas as pd

#Setting for pandas to show all columns
pd.set_option('display.max_columns', None)


#For GIS Analysis
import arcpy

#GIS Libraries and credentials
from arcgis.gis import GIS
from IPython.display import display
from arcgis.features import enrich_data
from arcgis.features import FeatureLayerCollection
from arcgis.geoenrichment import *
gis = GIS()

# %%
house_transactions = pd.read_csv('./Data/House_Prices/last_year_house_transactions_london.csv',sep=',')
uk_postcodes = pd.read_csv('./Data/House_Prices/ukpostcodes.csv',sep=',')

# %%
house_transactions.head()
# Out:
#             Transaction unique identifier   Price Date of Transfer  postcode  \
# 0  {68FEB20C-3FF9-38DA-E053-6C04A8C051AE}  460000       11/24/2017    N3 2FH
# 1  {68FEB20C-4001-38DA-E053-6C04A8C051AE}  332000       11/20/2017   E14 0HT
# 2  {68FEB20C-4007-38DA-E053-6C04A8C051AE}  210000       11/27/2017  UB10 8AU
# 3  {68FEB20C-400F-38DA-E053-6C04A8C051AE}  260000        10/6/2017   NW2 6JH
# 4  {68FEB20C-4014-38DA-E053-6C04A8C051AE}  375000       11/30/2017   NW6 5BA
#
#   Property Type           Town
# 0             F         BARNET
# 1             F  TOWER HAMLETS
# 2             F     HILLINGDON
# 3             F          BRENT
# 4             F          BRENT

# %%
uk_postcodes.head()
# Out:
#    id  postcode   latitude  longitude
# 0   1  AB10 1XG  57.144165  -2.114848
# 1   2  AB10 6RN  57.137880  -2.121487
# 2   3  AB10 7JB  57.124274  -2.127190
# 3   4  AB11 5QN  57.142701  -2.093295
# 4   5  AB11 6UL  57.137547  -2.112233

# %%
house_transactions = pd.merge(house_transactions,uk_postcodes, on='postcode')
house_transactions.head()
# Out:
#             Transaction unique identifier   Price Date of Transfer  postcode  \
# 0  {68FEB20C-4001-38DA-E053-6C04A8C051AE}  332000       11/20/2017   E14 0HT
# 1  {64342BFD-B07B-422C-E053-6C04A8C0FB8A}  325000        8/16/2017   E14 0HT
# 2  {68FEB20C-4007-38DA-E053-6C04A8C051AE}  210000       11/27/2017  UB10 8AU
# 3  {666758D7-90D6-3363-E053-6B04A8C0D74E}  520000       11/27/2017  UB10 8AU
# 4  {68FEB20C-400F-38DA-E053-6C04A8C051AE}  260000        10/6/2017   NW2 6JH
#
#   Property Type           Town       id   latitude  longitude
# 0             F  TOWER HAMLETS  1250232  51.514245   0.001029
# 1             F  TOWER HAMLETS  1250232  51.514245   0.001029
# 2             F     HILLINGDON   124987  51.560992  -0.468725
# 3             F     HILLINGDON   124987  51.560992  -0.468725
# 4             F          BRENT   637800  51.558771  -0.246120

# %%
house_transactions = house_transactions.drop(labels=['id'], axis=1)
house_transactions.head()
# Out:
#             Transaction unique identifier   Price Date of Transfer  postcode  \
# 0  {68FEB20C-4001-38DA-E053-6C04A8C051AE}  332000       11/20/2017   E14 0HT
# 1  {64342BFD-B07B-422C-E053-6C04A8C0FB8A}  325000        8/16/2017   E14 0HT
# 2  {68FEB20C-4007-38DA-E053-6C04A8C051AE}  210000       11/27/2017  UB10 8AU
# 3  {666758D7-90D6-3363-E053-6B04A8C0D74E}  520000       11/27/2017  UB10 8AU
# 4  {68FEB20C-400F-38DA-E053-6C04A8C051AE}  260000        10/6/2017   NW2 6JH
#
#   Property Type           Town   latitude  longitude
# 0             F  TOWER HAMLETS  51.514245   0.001029
# 1             F  TOWER HAMLETS  51.514245   0.001029
# 2             F     HILLINGDON  51.560992  -0.468725
# 3             F     HILLINGDON  51.560992  -0.468725
# 4             F          BRENT  51.558771  -0.246120

# %%
#how many nulls?
pd.DataFrame(house_transactions.isnull().sum().sort_values(ascending=False), columns = ['Number of Null']).head(20)
# Out:
#                                Number of Null
# longitude                                   0
# latitude                                    0
# Town                                        0
# Property Type                               0
# postcode                                    0
# Date of Transfer                            0
# Price                                       0
# Transaction unique identifier               0

# %%
house_transactions.to_csv('./Data/House_Prices/house_transactions_geolocated.csv',
                         index=False)

# %% [markdown]
# **Create Shapefile**

# %%
#we create the shapefile
arcpy.env.workspace = './Data/Shapefiles'
arcpy.management.XYTableToPoint('./Data/House_Prices/house_transactions_geolocated.csv','./Data/Shapefiles/house_transactions.shp',
                                "longitude", "latitude", "",
                                arcpy.SpatialReference(4326, 115700))
# Out:
# <Result '.\\Data\\Shapefiles\\house_transactions.shp'>

# %% [markdown]
# ## Hotels

# %%
#List of hotels, selenium scraper
hotels_list = pd.read_csv('./Data/Hotels/hotel_list_london.csv',
                    names=['Name','Price_Night_USD','Total_Reviews','Stars_Rating','Ranking_best_value','Link'])
hotels_list = hotels_list.drop(labels='Ranking_best_value', axis=1)
hotels_list.head()
# Out:
#                                    Name  Price_Night_USD  Total_Reviews  \
# 0                       The Arch London            257.0           1992
# 1    The Pelham – Starhotels Collezione            264.0            940
# 2  Premier Inn London Kings Cross Hotel            160.0           4899
# 3     Mondrian London at Sea Containers            286.0           4289
# 4                 The Royal Horseguards            205.0           5188
#
#    Stars_Rating                                               Link
# 0           5.0  https://www.tripadvisor.com/Hotel_Review-g1863...
# 1           4.5  https://www.tripadvisor.com/Hotel_Review-g1863...
# 2           4.5  https://www.tripadvisor.com/Hotel_Review-g1863...
# 3           4.5  https://www.tripadvisor.com/Hotel_Review-g1863...
# 4           4.5  https://www.tripadvisor.com/Hotel_Review-g1863...

# %%
#Details of hotels, including the address that we will merge
hotels_details = pd.read_csv('./Data/Hotels/hotel_details_london.csv')
hotels_details.head()
# Out:
#                      h_address  postcode  \
# 0   50 Great Cumberland Place    W1H 7FD
# 1  100 Shoreditch High Street     E1 6JQ
# 2      199 - 206 High Holborn   WC1V 7BD
# 3        10 Manchester Street    W1U 4DG
# 4            108 Baker Street    W1U 6LJ
#
#                                          h_amenities  \
# 0  Restaurant,Free High Speed Internet (WiFi),Fit...
# 1  Restaurant,Room Service,Fitness Center with Gy...
# 2  Free High Speed Internet (WiFi),Room Service,R...
# 3  Room Service,Restaurant,Free High Speed Intern...
# 4  Room Service,Fitness Center with Gym / Workout...
#
#                                               h_link  h_ranking_users  h_star  \
# 0  https://www.tripadvisor.com/Hotel_Review-g1863...              9.0     5.0
# 1  https://www.tripadvisor.com/Hotel_Review-g1863...            363.0     5.0
# 2  https://www.tripadvisor.com/Hotel_Review-g1863...             76.0     4.0
# 3  https://www.tripadvisor.com/Hotel_Review-g1863...            238.0     4.0
# 4  https://www.tripadvisor.com/Hotel_Review-g1863...            365.0     4.0
#
#    r_average  r_excellent  r_poor  r_terrible  r_very_good
# 0       48.0       1480.0     7.0         5.0        215.0
# 1      161.0        531.0    63.0        65.0        320.0
# 2       78.0       1167.0    15.0         6.0        383.0
# 3       74.0        464.0    25.0        19.0        207.0
# 4      312.0        914.0   127.0        76.0        814.0

# %%
hotels_details = pd.merge(hotels_details,uk_postcodes, on='postcode')
hotels_details = hotels_details.drop(labels='id',axis=1)
hotels_details.head()
# Out:
#                      h_address  postcode  \
# 0   50 Great Cumberland Place    W1H 7FD
# 1  100 Shoreditch High Street     E1 6JQ
# 2      199 - 206 High Holborn   WC1V 7BD
# 3        10 Manchester Street    W1U 4DG
# 4            108 Baker Street    W1U 6LJ
#
#                                          h_amenities  \
# 0  Restaurant,Free High Speed Internet (WiFi),Fit...
# 1  Restaurant,Room Service,Fitness Center with Gy...
# 2  Free High Speed Internet (WiFi),Room Service,R...
# 3  Room Service,Restaurant,Free High Speed Intern...
# 4  Room Service,Fitness Center with Gym / Workout...
#
#                                               h_link  h_ranking_users  h_star  \
# 0  https://www.tripadvisor.com/Hotel_Review-g1863...              9.0     5.0
# 1  https://www.tripadvisor.com/Hotel_Review-g1863...            363.0     5.0
# 2  https://www.tripadvisor.com/Hotel_Review-g1863...             76.0     4.0
# 3  https://www.tripadvisor.com/Hotel_Review-g1863...            238.0     4.0
# 4  https://www.tripadvisor.com/Hotel_Review-g1863...            365.0     4.0
#
#    r_average  r_excellent  r_poor  r_terrible  r_very_good   latitude  \
# 0       48.0       1480.0     7.0         5.0        215.0  51.515962
# 1      161.0        531.0    63.0        65.0        320.0  51.525743
# 2       78.0       1167.0    15.0         6.0        383.0  51.516893
# 3       74.0        464.0    25.0        19.0        207.0  51.518800
# 4      312.0        914.0   127.0        76.0        814.0  51.520914
#
#    longitude
# 0  -0.159802
# 1  -0.077353
# 2  -0.122558
# 3  -0.153879
# 4  -0.156705

# %%
#cheking null values
pd.DataFrame(hotels_details.isnull().sum())
# Out:
#                    0
# h_address          0
# postcode           0
# h_amenities        5
# h_link             0
# h_ranking_users   69
# h_star           114
# r_average         17
# r_excellent       17
# r_poor            17
# r_terrible        17
# r_very_good       17
# latitude           0
# longitude          0

# %%
#merge of the two tables by the hotel link
hotels = pd.merge(hotels_list,hotels_details, left_on='Link', right_on='h_link').reset_index()
hotels.drop(labels='h_link',axis=1, inplace=True)
hotels.head()
# Out:
#    index                                  Name  Price_Night_USD  \
# 0      0                       The Arch London            257.0
# 1      1    The Pelham – Starhotels Collezione            264.0
# 2      2  Premier Inn London Kings Cross Hotel            160.0
# 3      3     Mondrian London at Sea Containers            286.0
# 4      4                 The Royal Horseguards            205.0
#
#    Total_Reviews  Stars_Rating  \
# 0           1992           5.0
# 1            940           4.5
# 2           4899           4.5
# 3           4289           4.5
# 4           5188           4.5
#
#                                                 Link  \
# 0  https://www.tripadvisor.com/Hotel_Review-g1863...
# 1  https://www.tripadvisor.com/Hotel_Review-g1863...
# 2  https://www.tripadvisor.com/Hotel_Review-g1863...
# 3  https://www.tripadvisor.com/Hotel_Review-g1863...
# 4  https://www.tripadvisor.com/Hotel_Review-g1863...
#
#                     h_address  postcode  \
# 0  50 Great Cumberland Place    W1H 7FD
# 1          15 Cromwell Place    SW7 2LA
# 2             26-30 York Way     N1 9AA
# 3            20 Upper Ground    SE1 9PD
# 4          2 Whitehall Court   SW1A 2EJ
#
#                                          h_amenities  h_ranking_users  h_star  \
# 0  Restaurant,Free High Speed Internet (WiFi),Fit...              9.0     5.0
# 1  Restaurant,Room Service,Bar/Lounge,Fitness Cen...            191.0     5.0
# 2  Restaurant,Bar/Lounge,Free Internet,Air Condit...            181.0     4.0
# 3  Room Service,Bar/Lounge,Free High Speed Intern...             92.0     5.0
# 4  Room Service,Restaurant,Fitness Center with Gy...            175.0     5.0
#
#    r_average  r_excellent  r_poor  r_terrible  r_very_good   latitude  \
# 0       48.0       1480.0     7.0         5.0        215.0  51.515962
# 1       68.0        534.0    22.0         5.0        214.0  51.494367
# 2      350.0       2376.0   130.0        76.0       1506.0  51.531269
# 3      199.0       2900.0    52.0        36.0        721.0  51.508412
# 4      352.0       3210.0   147.0        66.0       1006.0  51.505814
#
#    longitude
# 0  -0.159802
# 1  -0.175074
# 2  -0.122325
# 3  -0.106932
# 4  -0.124186

# %%
hotels.to_csv('./Data/Hotels/hotels_london.csv')

# %% [markdown]
# ### GIS Enriching of datasets
#
# We want to add the following around each of the hotels:
#
# - Purchasing Power per Capita
# - Average of household size
# - Total household
# - Ratio of each age group (there are 4 of them)
# - Traveltime to the main city centre, finantial centre and Canary Wharf

# %%
hotels.shape #to check number of hotels
# Out:
# (1063, 18)

# %% [markdown]
# **Create Shapefile**

# %%
#we create the shapefile
arcpy.env.workspace = './Data/Shapefiles'
arcpy.management.XYTableToPoint('./Data/Hotels/hotels_london.csv','./Data/Shapefiles/hotels.shp',
                                "longitude", "latitude", "",
                                arcpy.SpatialReference(4326, 115700))
# Out:
# <Result '.\\Data\\Shapefiles\\hotels.shp'>

# %% [markdown]
# #### Publish to GIS for enriching

# %%
#Publish to GIS
hotels_csv = './Data/Hotels/hotels_london.csv'
item_prop = {'title':'hotels_london_tripadvisor'} #name of the layer in AGOL
#Try to add the csv to agol, if item exists will delete and add again
csv_to_publish = gis.content.add(item_properties=item_prop, data=hotels_csv)
hotels_shp = csv_to_publish.publish()
hotels_shp
# Out:
# <Item title:"hotels_london_tripadvisor" type:Feature Layer Collection owner:nacho.moreno_JLLesp>

# %% [markdown]
# **Enrich dataset**

# %%
uk = Country.get('GB')
uk.properties.datasets

datasets_esri = uk.data_collections

#we save in a CSV the data name sos we can gather the one sof interest
datasets_esri.to_csv('./Data/Shapefiles/datasets_esri.csv')

# %%
#We get the dataset in case has already been published
search_results = gis.content.search('title:hotels_london_tripadvisor', 'Feature Layer')
hotels_shp = search_results[0]
hotels_shp
# Out:
# <Item title:"hotels_london_tripadvisor" type:Feature Layer Collection owner:nacho.moreno_JLLesp>

# %%
#Enrich the dataset
data_collections = ['KeyFacts']

analysis_variables= ['KeyFacts.PAGE01_CY', #2017 Total Population Age 0-14
                     'KeyFacts.PAGE02_CY', #15-29
                     'KeyFacts.PAGE03_CY', #30-44
                     'KeyFacts.PAGE04_CY', #45-59
                     'KeyFacts.PAGE05CY', # >60
                     'KeyFacts.TOTPOP_CY', #Total populations
                     'KeyFacts.TOTHH_CY', # Total Households
                     'KeyFacts.HTYP01A_CY', #households with Single Person
                     'KeyFacts.PPPC_CY', #Purchasing Power per Capita
                     'KeyFacts.AVGHHSZ_CY', #Average Household Size
                    ]

#hotels_enriched = enrich_data.enrich_layer(hotels_shp, buffer_type='StraightLine', distance=0.5 ,units='Kilometers', 
                                         data_collections= data_collections, analysis_variables = analysis_variables)

#How to transform a feature collection to a df, first we 'query' teh feature collection adn a 
#Featureset is returned, then we use the df method to transform to a pd dataframe 

#Documentation here https://esri.github.io/arcgis-python-api/apidoc/html/arcgis.features.toc.html#featurecollection and
# here: https://esri.github.io/arcgis-python-api/apidoc/html/arcgis.features.toc.html#featureset
hotels_enriched_df = hotels_enriched.query().df

# %%
#We export teh shapefile for further analysis

hotels_enriched.query().save(save_location= './Data/Shapefiles',
     out_name='hotels_enriched', encoding=None)

#Lets change the name of the columns and clean the data
hotels_enriched_df = hotels_enriched_df.drop(['HasData', 'ID', 'OBJECTID', 'ENRICH_FID', 'aggregationMethod', 'areaType', 'bufferUnits', 'sourceCountry', 'SHAPE' ], axis=1)
hotels_enriched_df = hotels_enriched_df.rename(index=str, columns={"PAGE01_CY": "p_b_14", 
                                                               "PAGE02_CY": "p15_29",
                                                               "PAGE03_CY": "p30_44",
                                                               "PAGE04_CY": "p45_59",
                                                               "PAGE05_CY": "p_m_60",
                                                               "TOTPOP_CY": "tot_pop",
                                                               "TOTHH_CY": "tot_hhs",
                                                               "HTYP01A_CY": "single_hhs",
                                                               "PPPC_CY": "ppc",
                                                               "AVGHHSZ_CY": "hh_size"})

#Just to check we have the right data and save it ot a new dataframe and CSV so we dont need to run everytime
hotels_enriched_df.head(5)
# Out:
#    hh_size  single_hhs                                               Link  \
# 0      1.8        2844  https://www.tripadvisor.com/Hotel_Review-g1863...
# 1      3.5         602  https://www.tripadvisor.com/Hotel_Review-g1863...
# 2      1.9        1798  https://www.tripadvisor.com/Hotel_Review-g1863...
# 3      2.5        1772  https://www.tripadvisor.com/Hotel_Review-g1863...
# 4      1.9        1311  https://www.tripadvisor.com/Hotel_Review-g1863...
#
#                                    Name  p_b_14  p15_29  p30_44  p45_59  \
# 0                       The Arch London    1313    2291    3237    1679
# 1                          Ruskin Hotel    2775    2869    3168    1966
# 2    The Pelham – Starhotels Collezione    1205    1360    1957    1495
# 3  Premier Inn London Kings Cross Hotel    1629    4421    2335    1489
# 4     Mondrian London at Sea Containers     351    2164    1082     824
#
#         ppc  Price_Night_USD  Stars_Rating  tot_hhs  tot_pop  Total_Reviews  \
# 0  45036.36            257.0           5.0     5598    10274           1992
# 1  14963.16             56.0           3.5     3451    12243            626
# 2  56240.80            264.0           4.5     3874     7419            940
# 3  23642.09            160.0           4.5     4344    10974           4899
# 4  26184.80            286.0           4.5     2618     5073           4289
#
#    bufferRadii bufferUnitsAlias                   h_address  \
# 0          0.5       Kilometers  50 Great Cumberland Place
# 1          0.5       Kilometers      386 High Street North
# 2          0.5       Kilometers          15 Cromwell Place
# 3          0.5       Kilometers             26-30 York Way
# 4          0.5       Kilometers            20 Upper Ground
#
#                                          h_amenities  h_ranking_users  h_star  \
# 0  Restaurant,Free High Speed Internet (WiFi),Fit...              9.0     5.0
# 1  Free Parking,Bar/Lounge,Free High Speed Intern...            604.0     3.0
# 2  Restaurant,Room Service,Bar/Lounge,Fitness Cen...            191.0     5.0
# 3  Restaurant,Bar/Lounge,Free Internet,Air Condit...            181.0     4.0
# 4  Room Service,Bar/Lounge,Free High Speed Intern...             92.0     5.0
#
#    index_   latitude  longitude postcode  r_average  r_excellent  r_poor  \
# 0       0  51.515962  -0.159802  W1H 7FD       48.0       1480.0     7.0
# 1     500  51.544138   0.049934  E12 6PH       60.0        130.0    31.0
# 2       1  51.494367  -0.175074  SW7 2LA       68.0        534.0    22.0
# 3       2  51.531269  -0.122325   N1 9AA      350.0       2376.0   130.0
# 4       3  51.508412  -0.106932  SE1 9PD      199.0       2900.0    52.0
#
#    r_terrible  r_very_good
# 0         5.0        215.0
# 1        33.0        136.0
# 2         5.0        214.0
# 3        76.0       1506.0
# 4        36.0        721.0

# %%
#Lets save the data in a CSV
hotels_enriched_df.to_csv('./Data/Hotels/hotels_enriched.csv')

# %%
#Load data and inspect
hotels_enriched = pd.read_csv('./Data/Hotels/hotels_enriched.csv')
hotels_enriched.head()
# Out:
#    Unnamed: 0  hh_size  single_hhs  \
# 0           0      1.8        2844
# 1           1      3.5         602
# 2           2      1.9        1798
# 3           3      2.5        1772
# 4           4      1.9        1311
#
#                                                 Link  \
# 0  https://www.tripadvisor.com/Hotel_Review-g1863...
# 1  https://www.tripadvisor.com/Hotel_Review-g1863...
# 2  https://www.tripadvisor.com/Hotel_Review-g1863...
# 3  https://www.tripadvisor.com/Hotel_Review-g1863...
# 4  https://www.tripadvisor.com/Hotel_Review-g1863...
#
#                                    Name  p_b_14  p15_29  p30_44  p45_59  \
# 0                       The Arch London    1313    2291    3237    1679
# 1                          Ruskin Hotel    2775    2869    3168    1966
# 2    The Pelham – Starhotels Collezione    1205    1360    1957    1495
# 3  Premier Inn London Kings Cross Hotel    1629    4421    2335    1489
# 4     Mondrian London at Sea Containers     351    2164    1082     824
#
#         ppc  Price_Night_USD  Stars_Rating  tot_hhs  tot_pop  Total_Reviews  \
# 0  45036.36            257.0           5.0     5598    10274           1992
# 1  14963.16             56.0           3.5     3451    12243            626
# 2  56240.80            264.0           4.5     3874     7419            940
# 3  23642.09            160.0           4.5     4344    10974           4899
# 4  26184.80            286.0           4.5     2618     5073           4289
#
#    bufferRadii bufferUnitsAlias                   h_address  \
# 0          0.5       Kilometers  50 Great Cumberland Place
# 1          0.5       Kilometers      386 High Street North
# 2          0.5       Kilometers          15 Cromwell Place
# 3          0.5       Kilometers             26-30 York Way
# 4          0.5       Kilometers            20 Upper Ground
#
#                                          h_amenities  h_ranking_users  h_star  \
# 0  Restaurant,Free High Speed Internet (WiFi),Fit...              9.0     5.0
# 1  Free Parking,Bar/Lounge,Free High Speed Intern...            604.0     3.0
# 2  Restaurant,Room Service,Bar/Lounge,Fitness Cen...            191.0     5.0
# 3  Restaurant,Bar/Lounge,Free Internet,Air Condit...            181.0     4.0
# 4  Room Service,Bar/Lounge,Free High Speed Intern...             92.0     5.0
#
#    index_   latitude  longitude postcode  r_average  r_excellent  r_poor  \
# 0       0  51.515962  -0.159802  W1H 7FD       48.0       1480.0     7.0
# 1     500  51.544138   0.049934  E12 6PH       60.0        130.0    31.0
# 2       1  51.494367  -0.175074  SW7 2LA       68.0        534.0    22.0
# 3       2  51.531269  -0.122325   N1 9AA      350.0       2376.0   130.0
# 4       3  51.508412  -0.106932  SE1 9PD      199.0       2900.0    52.0
#
#    r_terrible  r_very_good
# 0         5.0        215.0
# 1        33.0        136.0
# 2         5.0        214.0
# 3        76.0       1506.0
# 4        36.0        721.0

# %% [markdown]
# #### Airbnb Data
#
# We have prefiltered the data to take into account, only private rooms, with a review in the last 9 months, more than 10 reviews and with availability.

# %%
airbnb = pd.read_csv('./Data/Airbnb/airbnb_listings_for_project.csv')
airbnb.head()
# Out:
#       id                         listing_url  host_id  \
# 0   9554   https://www.airbnb.com/rooms/9554    31655
# 1  13913  https://www.airbnb.com/rooms/13913    54730
# 2  17402  https://www.airbnb.com/rooms/17402    67564
# 3  25123  https://www.airbnb.com/rooms/25123   103583
# 4  26223  https://www.airbnb.com/rooms/26223   110865
#
#                                    host_url host_name  host_since  \
# 0   https://www.airbnb.com/users/show/31655       Guy       40039
# 1   https://www.airbnb.com/users/show/54730     Alina       40133
# 2   https://www.airbnb.com/users/show/67564       Liz       40182
# 3  https://www.airbnb.com/users/show/103583     Grace       40273
# 4  https://www.airbnb.com/users/show/110865     Paulo       40287
#
#                      host_location  \
# 0  London, England, United Kingdom
# 1  London, England, United Kingdom
# 2  London, England, United Kingdom
# 3  London, England, United Kingdom
# 4  London, England, United Kingdom
#
#                                           host_about zipcode   latitude  \
# 0  Please contact me before booking! Please see d...  N8 0EY  51.587767
# 1  I am a Multi-Media Visual Artist and Creative ...    N4 3  51.568017
# 2  Hello!\r\n\r\nWe are Liz and Jack. We look for...  W1T4BP  51.520982
# 3  Easy going, friendly\r\n\r\nAttentive to detai...  NW11 9  51.572243
# 4  Originally from Southern Europe, and now livin...    N1 2  51.541680
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0  -0.105666                 f     Apartment     Private room             2
# 1  -0.111208                 t     Apartment     Private room             2
# 2  -0.140024                 t     Apartment  Entire home/apt             6
# 3  -0.209060                 t         House     Private room             2
# 4  -0.102065                 t     Apartment  Entire home/apt             4
#
#    bathrooms  bedrooms  beds  bed_type  price  guests_included  \
# 0        NaN       1.0   1.0  Real Bed     35                1
# 1        1.0       1.0   1.0  Real Bed     45                1
# 2        2.0       3.0   3.0  Real Bed    300                4
# 3        1.5       1.0   1.0  Real Bed     29                1
# 4        1.0       1.0   3.0  Real Bed    150                4
#
#   calendar_updated has_availability  availability_30  availability_60  \
# 0      2 weeks ago                t               13               21
# 1       a week ago                t               29               59
# 2            today                t               13               25
# 3      5 weeks ago                t                4                4
# 4            today                t               29               45
#
#    availability_90  availability_365  calendar_last_scraped  \
# 0               21               262                  43321
# 1               89               364                  43321
# 2               49               135                  43321
# 3               10               285                  43321
# 4               75               350                  43321
#
#    number_of_reviews  last_review  review_scores_rating
# 0                131      43315.0                  97.0
# 1                 14      43268.0                  95.0
# 2                 31      43313.0                  93.0
# 3                114      43221.0                  95.0
# 4                 54      43308.0                  84.0

# %% [markdown]
# **Create shapefile**

# %%
#we create the shapefile
arcpy.env.workspace = './Data/Shapefiles'
arcpy.management.XYTableToPoint('./Data/Airbnb/airbnb_listings_for_project.csv','./Data/Shapefiles/airbnb.shp',
                                "longitude", "latitude", "",
                                arcpy.SpatialReference(4326, 115700))
# Out:
# <Result '.\\Data\\Shapefiles\\airbnb.shp'>

# %% [markdown]
# ### Restaurants Dataset
#
# Steps to follow:
#
# - Read both datasets and merge by link
# - Create Shapefile (already have coordinates)

# %%
restaurant_list = pd.read_csv('./Data/Restaurants/rest_list_london.csv')
restaurant_list.head()
# Out:
#              Restaurant Name Price Range  \
# 0  Kama Sushi @ Sticky Mango        $$$$
# 1             Amrutha Lounge    $$ - $$$
# 2               Humble Grape    $$ - $$$
# 3            The Lounge Cafe           $
# 4        Pizza Union Dalston           $
#
#                                         Cuisine type  Number of reviews  \
# 0  Japanese, Sushi, Asian, Vegetarian Friendly, G...                 88
# 1  Indian, Asian, Thai, Healthy, Vegetarian Frien...                160
# 2  European, Wine Bar, Vegan Options, Vegetarian ...                169
# 3  British, Vegetarian Friendly, Vegan Options, G...                131
# 4  Italian, Pizza, Fast Food, Vegetarian Friendly...                368
#
#    Reviews rating (out of 5)  Ranking  \
# 0                        5.0      1.0
# 1                        5.0      2.0
# 2                        5.0      3.0
# 3                        5.0      4.0
# 4                        5.0      5.0
#
#                                      Restaurant Link
# 0  https://www.tripadvisor.com/Restaurant_Review-...
# 1  https://www.tripadvisor.com/Restaurant_Review-...
# 2  https://www.tripadvisor.com/Restaurant_Review-...
# 3  https://www.tripadvisor.com/Restaurant_Review-...
# 4  https://www.tripadvisor.com/Restaurant_Review-...

# %%
restaurant_details = pd.read_csv('./Data/Restaurants/rest_details_london.csv')
restaurant_details.head()
# Out:
#                                         r_address  r_data      r_lat  \
# 0               91 Stamford St , London SE1 9NR,      NaN  51.506176
# 1  38C Kensington Church Street , London W8 4BX,      NaN  51.504189
# 2    34-38 Southampton Street , London WC2E 7HG,      NaN  51.510845
# 3           1A Launceston Place , London W8 5RL,      NaN  51.499207
# 4                28 Church Row , London NW3 6UP,      NaN  51.555576
#
#                                               r_link    r_long
# 0  https://www.tripadvisor.com/Restaurant_Review-... -0.109894
# 1  https://www.tripadvisor.com/Restaurant_Review-... -0.192753
# 2  https://www.tripadvisor.com/Restaurant_Review-... -0.121941
# 3  https://www.tripadvisor.com/Restaurant_Review-... -0.185377
# 4  https://www.tripadvisor.com/Restaurant_Review-... -0.178780

# %%
#Merging both datasets and saving the results to csv too
restaurants = pd.merge(restaurant_list,restaurant_details, left_on='Restaurant Link', right_on='r_link')
restaurants.drop(labels='r_link',axis=1, inplace=True)
restaurants.head()
# Out:
#              Restaurant Name Price Range  \
# 0  Kama Sushi @ Sticky Mango        $$$$
# 1             Amrutha Lounge    $$ - $$$
# 2               Humble Grape    $$ - $$$
# 3            The Lounge Cafe           $
# 4        Pizza Union Dalston           $
#
#                                         Cuisine type  Number of reviews  \
# 0  Japanese, Sushi, Asian, Vegetarian Friendly, G...                 88
# 1  Indian, Asian, Thai, Healthy, Vegetarian Frien...                160
# 2  European, Wine Bar, Vegan Options, Vegetarian ...                169
# 3  British, Vegetarian Friendly, Vegan Options, G...                131
# 4  Italian, Pizza, Fast Food, Vegetarian Friendly...                368
#
#    Reviews rating (out of 5)  Ranking  \
# 0                        5.0      1.0
# 1                        5.0      2.0
# 2                        5.0      3.0
# 3                        5.0      4.0
# 4                        5.0      5.0
#
#                                      Restaurant Link  \
# 0  https://www.tripadvisor.com/Restaurant_Review-...
# 1  https://www.tripadvisor.com/Restaurant_Review-...
# 2  https://www.tripadvisor.com/Restaurant_Review-...
# 3  https://www.tripadvisor.com/Restaurant_Review-...
# 4  https://www.tripadvisor.com/Restaurant_Review-...
#
#                                            r_address  r_data      r_lat  \
# 0                  91 Stamford St , London SE1 9NR,      NaN  51.506176
# 1               326 Garratt Lane , London SW18 4EJ,      NaN  51.443775
# 2           11-13 Theberton Street , London N1 0QY,      NaN  51.537575
# 3  Welford Centre 113 Chalkhill Road , London HA9...     NaN  51.564049
# 4               14 Kingsland Road , London E13 9PA,      NaN  51.546890
#
#      r_long
# 0 -0.109894
# 1 -0.189937
# 2 -0.103633
# 3 -0.276614
# 4 -0.075558

# %%
restaurants.to_csv('./Data/Restaurants/restaurants.csv')

# %%
#cheking null values
pd.DataFrame(restaurants.isnull().sum())
# Out:
#                                0
# Restaurant Name                0
# Price Range                 5283
# Cuisine type                3661
# Number of reviews              0
# Reviews rating (out of 5)      0
# Ranking                     1771
# Restaurant Link                0
# r_address                    196
# r_data                     18727
# r_lat                        117
# r_long                       117

# %% [markdown]
# **Create shapefile**

# %%
#we create the shapefile
arcpy.env.workspace = './Data/Shapefiles'
arcpy.management.XYTableToPoint('./Data/Restaurants/restaurants.csv','./Data/Shapefiles/restaurants.shp',
                                "r_long", "r_lat", "",
                                arcpy.SpatialReference(4326, 115700))
# Out:
# <Result '.\\Data\\Shapefiles\\restaurants.shp'>
